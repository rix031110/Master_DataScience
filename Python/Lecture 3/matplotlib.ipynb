# %%
import matplotlib.pyplot as plt
x= [1,2,3,4,5,6,7]
y=[7,8,9.5,3,-5,6,8]
plt.plot(x,y)
plt.title("Sample plot")
plt.xlabel("Days")
plt.ylabel("Rain mm")
plt.show() #it shows the chart

# %% [markdown]
# # Barchart

# %%
categories= ["Company A","Company B","Company C", "Company D"] #in barcharts we need ctaegories, not values on x axe
sales=[2,4,7,1]
value=[7,18,9,3]
colors=["green","blue","red","orange"]
plt.bar(categories,value,color= colors)
plt.title("Sample barchart")
plt.xlabel("North-West Companies")
plt.ylabel("Revenues in milions")
plt.xticks(rotation=45) #to change the rotation of names
plt.show()

# %%
import numpy as np

# %%
from mpl_toolkits.mplot3d import Axes3D as d3 #to plot a 3d version

categories= ["Company A","Company B","Company C", "Company D"] #in barcharts we need ctaegories, not values on x axe
value=[7,18,9,3]
colors=["green","blue","red","orange"]

fig=plt.figure() #let's create a figure, a cintainer im which there can be multiple plots
ax=fig.add_subplot(111,projection="3d") # it creates a grid of dimensions 1,1 plotting the figure 1 and announce that the subplot will be in 3d

x=np.arange(len(categories)) #prepare the subplot to have 4 element (the lenght of categories)

ax.bar(x, value, zdir="y", color=colors)#it creates the barchart, with a lemnght of z equal to the one of y axe (value)

plt.bar(categories,value,color= colors)
#plt.title("Sample barchart")
#plt.xlabel("North-West Companies")
#plt.ylabel("Revenues in milions")
#plt.xticks(rotation=45) #to change the rotation of names
plt.show()
