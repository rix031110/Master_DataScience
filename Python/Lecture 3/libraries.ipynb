# %%
import numpy as np

# %%
dir(np)
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
np.arange(start=100, stop=200, step=3)
# Out:
# array([100, 103, 106, 109, 112, 115, 118, 121, 124, 127, 130, 133, 136,
#        139, 142, 145, 148, 151, 154, 157, 160, 163, 166, 169, 172, 175,
#        178, 181, 184, 187, 190, 193, 196, 199])

# %%
from numpy import arange

# %%
arange(100,200,4)
# Out:
# array([100, 104, 108, 112, 116, 120, 124, 128, 132, 136, 140, 144, 148,
#        152, 156, 160, 164, 168, 172, 176, 180, 184, 188, 192, 196])

# %%
import math
import datetime as dt
print(math.sqrt(16))
now= dt.datetime.now()
now.strftime("%d/%m/%y %H:%M") #it gives a structure to the date
# Out:
# 4.0
# '18/02/26 09:57'

# %%
import random as rd
rd.randint(2,1000002) #oit generates a random number between 2 numbers
# Out:
# 482836

# %%
# !pip install requests

# %%
url= **
import requests #it gets a url and exptrapolate the text

response= requests.get (url)
response.text
# Out:
#   Cell In[30], line 1
#     url= **
#          ^
# SyntaxError: invalid syntax

# %%
import os 
os.getcwd() #it shows the current path of the directory
# Out:
# 'C:\\Users\\ricdo\\source\\MasterDS\\Lecture 3'

# %%
import csv
with open("my_data.csv") as f:
    reader=csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['id', 'name', 'surname', 'age']
# ['1', 'Sara', 'Albricci', '23']
# ['2', 'Sfudda', 'Catonga', '33']
# ['3', 'Luzzo', 'Merl', '44']

# %%
with open("my_data.csv") as f:
    reader=csv.DictReader(f)
    for row in reader:
        print(row["name"], row["age"])
# Out:
# Sara 23
# Sfudda 33
# Luzzo 44
