# %% [markdown]
# # Linear regression

# %%
"""
It is an algortihm that extracts a number from the features passed
"""
# Out:
# '\nIt is an algortihm that extracts a number from the features passed\n'
