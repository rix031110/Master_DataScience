# %%
max_distance=400
temperature=36.7
greet_ing= "Hello everyone"
isRaining= True

# %%
print(max_distance,temperature, greet_ing, isRaining)
# Out:
# 400 36.7 Hello everyone True

# %%
d=3.14259

# %%
int(d)
# Out:
# 3

# %%
float(42)
# Out:
# 42.0

# %%
k= 99.99
str(k)
float(k)
# Out:
# 99.99

# %%
int(
