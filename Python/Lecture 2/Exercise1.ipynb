# %%
if 10>5:
    print("Ten is greater than five!")
print("Today is sunny")
# Out:
# Ten is greater than five!
# Today is sunny

# %%
if 10>15:
    print("Ten is greater than five!")
else:
    print("It's lower")
    
print("Today is sunny")
# Out:
# It's lower
# Today is sunny

# %%
def sum(a,b):#the name can be of anykind
    """
    This function receives 2 parameters that are sumed together
    """
    result=a+b #  this is what the function does and should be associated to result
    return result #we return the result variable

# %%
sum("Mike", "Elisa")
# Out:
# 'MikeElisa'

# %%
building1= "Church"

# %%
building1_name="Office"

# %%
building1_height=30020

# %%
building1_name
# Out:
# 'Office'

# %%
type(building1_height)
# Out:
# int

# %%
is_valid=True

# %%
type(is_valid)
# Out:
# bool

# %%
type(3<5)
# Out:
# bool

# %%
d=str(is_valid)

# %%
d
# Out:
# 'True'

# %%
type(d)
# Out:
# str

# %%
age=40.45
is_valid=True
building1= "Church"
building1_height=30020
