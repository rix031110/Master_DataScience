# %%
s1= "Hello everyone"
s2= "Riccardo said 'Hello everyone'"
s3= """
    Riccardo is very good at:
    - coding
    - not much more
    """

# %%
name= "Riccardo"
print(f"Hello everyone, and you to\n {name},\n my dear!")
# Out:
# Hello everyone, and you to
#  Riccardo,
#  my dear!

# %%
s4= s1[:2]+s1[-2:]
s4
# Out:
# 'Hene'

# %%
s5= s1[:2].lower()+s1[-2:].upper()
s5
# Out:
# 'heNE'
